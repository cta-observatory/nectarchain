# %%
import logging
import os
import pathlib

logging.basicConfig(
    format="%(asctime)s %(name)s %(levelname)s %(message)s", level=logging.INFO
)
log = logging.getLogger(__name__)
log.handlers = logging.getLogger("__main__").handlers

from nectarchain.makers.calibration import (
    FlatFieldSPEHHVStdNectarCAMCalibrationTool,
    FlatFieldSPENominalStdNectarCAMCalibrationTool,
)

# %%
run_number = 3936

# %%
# !ls -lh $NECTARCAMDATA/runs/*
# Out:
# -rw-r--r-- 1 ggroller gamma    96  1 nov.  23:19 /data/users/ggroller/NECTARCAM//runs/CalibrationTool_run3942.h5
# -rwxr-xr-x 1 ggroller gamma  1,5G 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2608.0000.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,5G 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2608.0001.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,5G 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2608.0002.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,5G 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2608.0003.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1013M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2608.0004.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,1G 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2608.0005.fits.fz
# -rwxr-xr-x 1 ggroller gamma  988M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2609.0000.fits.fz
# -rwxr-xr-x 1 ggroller gamma  988M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2609.0001.fits.fz
# -rwxr-xr-x 1 ggroller gamma  988M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2609.0002.fits.fz
# -rwxr-xr-x 1 ggroller gamma  988M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2609.0003.fits.fz
# -rwxr-xr-x 1 ggroller gamma  607M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2609.0004.fits.fz
# -rwxr-xr-x 1 ggroller gamma  629M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2609.0005.fits.fz
# -rwxr-xr-x 1 ggroller gamma  988M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2630.0000.fits.fz
# -rwxr-xr-x 1 ggroller gamma  988M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2630.0001.fits.fz
# -rwxr-xr-x 1 ggroller gamma  988M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2630.0002.fits.fz
# -rwxr-xr-x 1 ggroller gamma  988M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2630.0003.fits.fz
# -rwxr-xr-x 1 ggroller gamma  851M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2630.0004.fits.fz
# -rwxr-xr-x 1 ggroller gamma  849M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2630.0005.fits.fz
# -rwxr-xr-x 1 ggroller gamma  988M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2631.0000.fits.fz
# -rwxr-xr-x 1 ggroller gamma  988M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2631.0001.fits.fz
# -rwxr-xr-x 1 ggroller gamma  988M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2631.0002.fits.fz
# -rwxr-xr-x 1 ggroller gamma  988M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2631.0003.fits.fz
# -rwxr-xr-x 1 ggroller gamma  782M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2631.0004.fits.fz
# -rwxr-xr-x 1 ggroller gamma  780M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2631.0005.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,1G 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2633.0000.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,1G 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2633.0001.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,1G 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2633.0002.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,1G 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2633.0003.fits.fz
# -rwxr-xr-x 1 ggroller gamma  718M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2633.0004.fits.fz
# -rwxr-xr-x 1 ggroller gamma  732M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2633.0005.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,2G 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2634.0000.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,2G 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2634.0001.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,2G 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2634.0002.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,2G 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2634.0003.fits.fz
# -rwxr-xr-x 1 ggroller gamma  815M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2634.0004.fits.fz
# -rwxr-xr-x 1 ggroller gamma  835M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run2634.0005.fits.fz
# -rwxr-xr-x 1 ggroller gamma  983M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3645.0000.fits.fz
# -rwxr-xr-x 1 ggroller gamma  983M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3645.0001.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,0G 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3731.0000.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,0G 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3731.0001.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1023M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3731.0002.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,0G 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3731.0003.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1023M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3731.0004.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,0G 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3731.0005.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,0G 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3731.0006.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,0G 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3731.0007.fits.fz
# -rwxr-xr-x 1 ggroller gamma  159M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3731.0008.fits.fz
# -rwxr-xr-x 1 ggroller gamma  175M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3731.0009.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1020M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3750.0000.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1020M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3750.0001.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1020M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3750.0002.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1020M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3750.0003.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1020M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3750.0004.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1020M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3750.0005.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1020M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3750.0006.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1020M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3750.0007.fits.fz
# -rwxr-xr-x 1 ggroller gamma  551M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3750.0008.fits.fz
# -rwxr-xr-x 1 ggroller gamma  551M 11 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3750.0009.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1016M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3784.0000.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1016M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3784.0001.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1016M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3784.0002.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1016M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3784.0003.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1016M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3784.0004.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1016M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3784.0005.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1016M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3784.0006.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1016M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3784.0007.fits.fz
# -rwxr-xr-x 1 ggroller gamma  245M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3784.0008.fits.fz
# -rwxr-xr-x 1 ggroller gamma  262M 25 avril  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3784.0009.fits.fz
# -rwxr-xr-x 1 ggroller gamma  677M 10 sept. 05:37 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3936.0000.fits.fz
# -rwxr-xr-x 1 ggroller gamma  696M 10 sept. 05:38 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3936.0001.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,5G 10 sept. 05:39 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3937.0000.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,5G 10 sept. 05:39 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3937.0001.fits.fz
# -rwxr-xr-x 1 ggroller gamma  799M 10 sept. 05:40 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3938.0000.fits.fz
# -rwxr-xr-x 1 ggroller gamma  799M 10 sept. 05:40 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3938.0001.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,2G  6 févr.  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3942.0000.fits.fz
# -rwxr-xr-x 1 ggroller gamma  1,2G  6 févr.  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3942.0001.fits.fz
# -rwxr-xr-x 1 ggroller gamma  317M  6 févr.  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3942.0002.fits.fz
# -rwxr-xr-x 1 ggroller gamma  326M  6 févr.  2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run3942.0003.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0000.fits.fz
# -rwxr-xr-x 1 ggroller gamma  995M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0001.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0002.fits.fz
# -rwxr-xr-x 1 ggroller gamma  995M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0003.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0004.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0005.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0006.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0007.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0008.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0009.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0010.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0011.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0012.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0013.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0014.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0015.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0016.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0017.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0018.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0019.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0020.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0021.fits.fz
# -rwxr-xr-x 1 ggroller gamma  995M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0022.fits.fz
# -rwxr-xr-x 1 ggroller gamma  995M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0023.fits.fz
# -rwxr-xr-x 1 ggroller gamma  995M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0024.fits.fz
# -rwxr-xr-x 1 ggroller gamma  995M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0025.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0026.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0027.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0028.fits.fz
# -rwxr-xr-x 1 ggroller gamma  995M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0029.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0030.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0031.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0032.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0033.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0034.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0035.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0036.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0037.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0038.fits.fz
# -rwxr-xr-x 1 ggroller gamma  995M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0039.fits.fz
# -rwxr-xr-x 1 ggroller gamma  995M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0040.fits.fz
# -rwxr-xr-x 1 ggroller gamma  995M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0041.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0042.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0043.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0044.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0045.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0046.fits.fz
# -rwxr-xr-x 1 ggroller gamma  994M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0047.fits.fz
# -rwxr-xr-x 1 ggroller gamma  619M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0048.fits.fz
# -rwxr-xr-x 1 ggroller gamma  620M 31 mai    2023 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4129.0049.fits.fz
# -rwxr-xr-x 1 ggroller gamma 1019M 10 janv. 20:32 /data/users/ggroller/NECTARCAM//runs/NectarCAM.Run4943.0000.fits.fz
#
# /data/users/ggroller/NECTARCAM//runs/charges:
# total 5,4G
# -rw-r--r-- 1 ggroller gamma  86M  2 déc.  18:56 ChargesNectarCAMCalibration_run3936_LocalPeakWindowSum_window_width_10_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma  87M  2 déc.  18:57 ChargesNectarCAMCalibration_run3936_LocalPeakWindowSum_window_width_11_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma  87M 28 nov.  15:44 ChargesNectarCAMCalibration_run3936_LocalPeakWindowSum_window_width_12_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma  90M 24 nov.  14:57 ChargesNectarCAMCalibration_run3936_LocalPeakWindowSum_window_width_16_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma  84M  2 déc.  18:54 ChargesNectarCAMCalibration_run3936_LocalPeakWindowSum_window_width_8_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma  85M  2 déc.  18:55 ChargesNectarCAMCalibration_run3936_LocalPeakWindowSum_window_width_9_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma 786K 23 nov.  23:46 ChargesNectarCAMCalibration_run3936_maxevents100_LocalPeakWindowSum_window_width_16_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma 2,3M 23 nov.  23:42 ChargesNectarCAMCalibration_run3936_maxevents300_LocalPeakWindowSum_window_width_16_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma 113M 24 nov.  15:42 ChargesNectarCAMCalibration_run3937_LocalPeakWindowSum_window_width_16_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma 117M 24 nov.  15:16 ChargesNectarCAMCalibration_run3938_LocalPeakWindowSum_window_width_16_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma 175M  4 déc.  09:58 ChargesNectarCAMCalibration_run3942_LocalPeakWindowSum_window_width_10_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma 176M  4 déc.  10:00 ChargesNectarCAMCalibration_run3942_LocalPeakWindowSum_window_width_11_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma 177M  4 déc.  08:56 ChargesNectarCAMCalibration_run3942_LocalPeakWindowSum_window_width_12_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma 179M 24 nov.  16:55 ChargesNectarCAMCalibration_run3942_LocalPeakWindowSum_window_width_16_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma 173M  4 déc.  09:55 ChargesNectarCAMCalibration_run3942_LocalPeakWindowSum_window_width_8_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma 175M  4 déc.  09:57 ChargesNectarCAMCalibration_run3942_LocalPeakWindowSum_window_width_9_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma  16M 24 nov.  10:51 ChargesNectarCAMCalibration_run3942_maxevents1300_LocalPeakWindowSum_window_width_16_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma  16M 24 nov.  10:51 ChargesNectarCAMCalibration_run3942_maxevents2000_LocalPeakWindowSum_window_width_16_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma 3,9M 24 nov.  10:23 ChargesNectarCAMCalibration_run3942_maxevents500_LocalPeakWindowSum_window_width_16_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma 3,6G 28 nov.  15:24 ChargesNectarCAMCalibration_run4129_LocalPeakWindowSum_window_width_16_window_shift_4.h5
# -rw-r--r-- 1 ggroller gamma 464K 10 janv. 20:33 ChargesNectarCAMCalibration_run4943_maxevents100_GlobalPeakWindowSum_window_width_16_window_shift_4.h5
#
# /data/users/ggroller/NECTARCAM//runs/waveforms:
# total 65G
# -rw-r--r-- 1 ggroller gamma 1,6G 28 nov.  15:43 WaveformsNectarCAMCalibration_run3936.h5
# -rw-r--r-- 1 ggroller gamma  14M 23 nov.  18:55 WaveformsNectarCAMCalibration_run3936_maxevents100.h5
# -rw-r--r-- 1 ggroller gamma  41M 23 nov.  18:56 WaveformsNectarCAMCalibration_run3936_maxevents300.h5
# -rw-r--r-- 1 ggroller gamma 3,3G 24 nov.  15:41 WaveformsNectarCAMCalibration_run3937.h5
# -rw-r--r-- 1 ggroller gamma 1,9G 24 nov.  15:15 WaveformsNectarCAMCalibration_run3938.h5
# -rw-r--r-- 1 ggroller gamma   96 12 janv. 14:07 WaveformsNectarCAMCalibration_run3942.h5
# -rw-r--r-- 1 ggroller gamma 298M 24 nov.  10:50 WaveformsNectarCAMCalibration_run3942_maxevents2000.h5
# -rw-r--r-- 1 ggroller gamma  75M 24 nov.  10:23 WaveformsNectarCAMCalibration_run3942_maxevents500.h5
# -rw-r--r-- 1 ggroller gamma  58G 27 nov.  21:51 WaveformsNectarCAMCalibration_run4129.h5
# -rw-r--r-- 1 ggroller gamma  68M 12 janv. 11:15 WaveformsNectarCAMCalibration_run4943_maxevents500.h5

# %%
tool = FlatFieldSPENominalStdNectarCAMCalibrationTool(
    progress_bar=True,
    method="LocalPeakWindowSum",
    extractor_kwargs={"window_width": 12, "window_shift": 4},
    multiproc=True,
    nproc=10,
    run_number=run_number,
    max_events=10000,
    log_level=20,
    reload_events=True,
    # events_per_slice = 200,
    asked_pixels_id=[52, 48],
    output_path=pathlib.Path(os.environ.get("NECTARCAMDATA", "/tmp"))
    / "tutorials/"
    / f"SPEfit_{run_number}.h5",
)
# Out:
# 2024-01-12 14:15:34,505 WARNING [nectarchain.makers.core] (core.__new__): the componentName in componentsList must be defined in the nectarchain.makers.component module, otherwise the import of the componentName will raise an error

# %%
tool
# Out:
# <b>FlatFieldSPENominalStdNectarCAMCalibrationTool</b>
# <p> <div class="document">
# <p>A class for data processing and computation on events from a specific run.</p>
# <dl class="docutils">
# <dt>Args:</dt>
# <dd>run_number (int): The ID of the run to be processed.
# max_events (int, optional): The maximum number of events to be loaded. Defaults to None.
# run_file (optional): The specific run file to be loaded.</dd>
# <dt>Example Usage:</dt>
# <dd><blockquote class="first">
# maker = EventsLoopMaker(run_number=1234, max_events=1000)
# maker.make(n_events=500)</blockquote>
# <p class="last">This currently uses data model version v5.0.0</p>
# </dd>
# </dl>
# </div>
#  </p>
# <table>
#     <colgroup>
#         <col span='1' style=' '>
#         <col span='1' style='width: 20em;'>
#         <col span='1' >
#     </colgroup>
#     <tbody>
# <tr><th>asked_pixels_id</th>
# <td style='text-align: left;'><span style='color:blue; max-width:30em;'>[52, 48]</span></td>
# <td style='text-align: left;'><i> (default: None)</i></td></tr>
# <tr><th>chunksize</th>
# <td style='text-align: left;'>1</td>
# <td style='text-align: left;'><i>The chunk size for multi-processing (default: 1)</i></td></tr>
# <tr><th>componentsList</th>
# <td style='text-align: left;'><span style='color:blue; max-width:30em;'>['FlatFieldSingleNominalSPEStdNectarCAMComponent']</span></td>
# <td style='text-align: left;'><i>. Possible values: ['ChargesComponent', 'WaveformsComponent', 'FlatFieldSingleNominalSPENectarCAMComponent', 'PhotoStatisticNectarCAMComponent', 'FlatFieldSingleNominalSPEStdNectarCAMComponent', 'FlatFieldSingleHHVSPENectarCAMComponent', 'FlatFieldSingleHHVSPEStdNectarCAMComponent', 'FlatFieldCombinedSPEStdNectarCAMComponent'] (default: traitlets.Undefined)</i></td></tr>
# <tr><th>config_files</th>
# <td style='text-align: left;'><span style='color:blue; max-width:30em;'>[]</span></td>
# <td style='text-align: left;'><i> (default: traitlets.Undefined)</i></td></tr>
# <tr><th>events_per_slice</th>
# <td style='text-align: left;'>None</td>
# <td style='text-align: left;'><i>number of events that will be treat before to pull the buffer and write to disk, if None, all the events will be loaded (default: None)</i></td></tr>
# <tr><th>extractor_kwargs</th>
# <td style='text-align: left;'><span style='color:blue; max-width:30em;'>{'window_<wbr>width': 12, 'window_<wbr>shift': 4}</span></td>
# <td style='text-align: left;'><i> (default: traitlets.Undefined)</i></td></tr>
# <tr><th>log_config</th>
# <td style='text-align: left;'><span style='color:blue; max-width:30em;'>{}</span></td>
# <td style='text-align: left;'><i> (default: traitlets.Undefined)</i></td></tr>
# <tr><th>log_datefmt</th>
# <td style='text-align: left;'>%Y-%m-%d %H:%M:%S</td>
# <td style='text-align: left;'><i>The date format used by logging formatters for %(asctime)s (default: %Y-%m-%d %H:%M:%S)</i></td></tr>
# <tr><th>log_file</th>
# <td style='text-align: left;'>None</td>
# <td style='text-align: left;'><i>Filename for the log (default: None)</i></td></tr>
# <tr><th>log_file_level</th>
# <td style='text-align: left;'>INFO</td>
# <td style='text-align: left;'><i>Logging Level for File Logging (default: INFO)</i></td></tr>
# <tr><th>log_format</th>
# <td style='text-align: left;'>[%(name)s]%(highlevel)s %(message)s</td>
# <td style='text-align: left;'><i>The Logging format template (default: [%(name)s]%(highlevel)s %(message)s)</i></td></tr>
# <tr><th>log_level</th>
# <td style='text-align: left;'><span style='color:blue; max-width:30em;'>20</span></td>
# <td style='text-align: left;'><i>Set the log level by value or name. (default: 30)</i></td></tr>
# <tr><th>logging_config</th>
# <td style='text-align: left;'><span style='color:blue; max-width:30em;'>{}</span></td>
# <td style='text-align: left;'><i> (default: traitlets.Undefined)</i></td></tr>
# <tr><th>max_events</th>
# <td style='text-align: left;'><span style='color:blue; max-width:30em;'>10000</span></td>
# <td style='text-align: left;'><i>maximum number of events to be loaded (default: None)</i></td></tr>
# <tr><th>method</th>
# <td style='text-align: left;'><span style='color:blue; max-width:30em;'>LocalPeakWindowSum</span></td>
# <td style='text-align: left;'><i>the charge extraction method (default: FullWaveformSum)</i></td></tr>
# <tr><th>multiproc</th>
# <td style='text-align: left;'>True</td>
# <td style='text-align: left;'><i>flag to active multi-processing (default: True)</i></td></tr>
# <tr><th>nproc</th>
# <td style='text-align: left;'><span style='color:blue; max-width:30em;'>10</span></td>
# <td style='text-align: left;'><i>The Number of cpu used for SPE fit (default: 8)</i></td></tr>
# <tr><th>output_path</th>
# <td style='text-align: left;'><span style='color:blue; max-width:30em;'>/<wbr>data/<wbr>users/<wbr>ggroller/<wbr>NECTARCAM/<wbr>tutorials/<wbr>SPEfit_<wbr>3936.h5</span></td>
# <td style='text-align: left;'><i>output filename (default: /data/users/ggroller/NECTARCAM/runs/EventsLoopNectarCAMCalibration_run-1.h5)</i></td></tr>
# <tr><th>overwrite</th>
# <td style='text-align: left;'>False</td>
# <td style='text-align: left;'><i> (default: False)</i></td></tr>
# <tr><th>pixels_id</th>
# <td style='text-align: left;'>None</td>
# <td style='text-align: left;'><i> (default: None)</i></td></tr>
# <tr><th>progress_bar</th>
# <td style='text-align: left;'><span style='color:blue; max-width:30em;'>True</span></td>
# <td style='text-align: left;'><i>show progress bar during processing (default: False)</i></td></tr>
# <tr><th>provenance_log</th>
# <td style='text-align: left;'><span style='color:blue; max-width:30em;'>/<wbr>home/<wbr>ggroller/<wbr>projects/<wbr>nectarchain/<wbr>notebooks/<wbr>tool_<wbr>implementation/<wbr>FlatFieldSPENominalStdNectarCAM.provenance.log</span></td>
# <td style='text-align: left;'><i> (default: traitlets.Undefined)</i></td></tr>
# <tr><th>quiet</th>
# <td style='text-align: left;'>False</td>
# <td style='text-align: left;'><i> (default: False)</i></td></tr>
# <tr><th>run_file</th>
# <td style='text-align: left;'>None</td>
# <td style='text-align: left;'><i>file name to be loaded (default: None)</i></td></tr>
# <tr><th>run_number</th>
# <td style='text-align: left;'><span style='color:blue; max-width:30em;'>3936</span></td>
# <td style='text-align: left;'><i>run number to be treated (default: -1)</i></td></tr>
# <tr><th>show_config</th>
# <td style='text-align: left;'>False</td>
# <td style='text-align: left;'><i>Instead of starting the Application, dump configuration to stdout (default: False)</i></td></tr>
# <tr><th>show_config_json</th>
# <td style='text-align: left;'>False</td>
# <td style='text-align: left;'><i>Instead of starting the Application, dump configuration to stdout (as JSON) (default: False)</i></td></tr>
#     </tbody>
# </table>
# <p><b>Components:</b>
# FlatFieldSPENominalStdNectarCAMCalibrationTool, HDF5TableWriter, LightNectarCAMEventSource, NectarCAMComponent, ChargesComponent, WaveformsComponent, FlatFieldSingleNominalSPENectarCAMComponent, PhotoStatisticNectarCAMComponent, FlatFieldSingleNominalSPEStdNectarCAMComponent, FlatFieldSingleHHVSPENectarCAMComponent, FlatFieldSingleHHVSPEStdNectarCAMComponent, FlatFieldCombinedSPEStdNectarCAMComponent
# </p>
# </div>

# %%
tool.initialize()
# Out:
# 2024-01-12 14:15:35,548 WARNING [nectarchain.FlatFieldSPENominalStdNectarCAM] (loader._handle_unrecognized_alias): Unrecognized alias: 'f', it will have no effect.
# 2024-01-12 14:15:35,553 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM] (tool.initialize): Loading config from '[]'
# 2024-01-12 14:15:35,557 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM] (tool.initialize): ctapipe version 0.19.1

# %%
tool.setup()
# Out:
# 2024-01-12 14:15:35,777 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM] (core.setup): setup of the Tool
# 2024-01-12 14:15:36,369 INFO [nectarchain.data.management] (management.findrun): Found 2 files matching /data/users/ggroller/NECTARCAM/runs/NectarCAM.Run3936.*.fits.fz
# 2024-01-12 14:15:36,370 INFO [nectarchain.makers.core] (core.load_run): /data/users/ggroller/NECTARCAM/runs/NectarCAM.Run3936.*.fits.fz will be loaded
# 2024-01-12 14:15:36,373 INFO [nectarchain.data.container.eventSource.LightNectarCAMEventSource] (eventsource.__init__): INPUT PATH = /data/users/ggroller/NECTARCAM/runs/NectarCAM.Run3936.0000.fits.fz
# 2024-01-12 14:15:36,374 INFO [nectarchain.data.container.eventSource.LightNectarCAMEventSource] (eventsource.__init__): Max events being read = 10000
# 2024-01-12 14:15:37,379 INFO [nectarchain.data.container.eventSource.LightNectarCAMEventSource] (__init__.__init__): Read 2 input files
# 2024-01-12 14:15:37,439 ctapipe.io.hdf5tableio.HDF5TableReader WARNING Table /tel_0/calibration is missing column time_correction for field time_correction of container <class 'ctapipe.containers.WaveformCalibrationContainer'>. It will be skipped.
# 2024-01-12 14:15:37,441 ctapipe.io.hdf5tableio.HDF5TableReader WARNING Table /tel_0/calibration is missing column n_pe for field n_pe of container <class 'ctapipe.containers.WaveformCalibrationContainer'>. It will be skipped.
# 2024-01-12 14:15:37,464 ctapipe.io.hdf5tableio.HDF5TableReader WARNING Table /tel_0/flatfield is missing column charge_mean for field charge_mean of container <class 'ctapipe.containers.FlatFieldContainer'>. It will be skipped.
# 2024-01-12 14:15:37,465 ctapipe.io.hdf5tableio.HDF5TableReader WARNING Table /tel_0/flatfield is missing column charge_median for field charge_median of container <class 'ctapipe.containers.FlatFieldContainer'>. It will be skipped.
# 2024-01-12 14:15:37,466 ctapipe.io.hdf5tableio.HDF5TableReader WARNING Table /tel_0/flatfield is missing column charge_std for field charge_std of container <class 'ctapipe.containers.FlatFieldContainer'>. It will be skipped.
# 2024-01-12 14:15:37,467 ctapipe.io.hdf5tableio.HDF5TableReader WARNING Table /tel_0/flatfield is missing column time_mean for field time_mean of container <class 'ctapipe.containers.FlatFieldContainer'>. It will be skipped.
# 2024-01-12 14:15:37,468 ctapipe.io.hdf5tableio.HDF5TableReader WARNING Table /tel_0/flatfield is missing column time_median for field time_median of container <class 'ctapipe.containers.FlatFieldContainer'>. It will be skipped.
# 2024-01-12 14:15:37,469 ctapipe.io.hdf5tableio.HDF5TableReader WARNING Table /tel_0/flatfield is missing column time_std for field time_std of container <class 'ctapipe.containers.FlatFieldContainer'>. It will be skipped.
# 2024-01-12 14:15:37,470 ctapipe.io.hdf5tableio.HDF5TableReader WARNING Table /tel_0/flatfield is missing column relative_gain_median for field relative_gain_median of container <class 'ctapipe.containers.FlatFieldContainer'>. It will be skipped.
# 2024-01-12 14:15:37,470 ctapipe.io.hdf5tableio.HDF5TableReader WARNING Table /tel_0/flatfield is missing column relative_gain_std for field relative_gain_std of container <class 'ctapipe.containers.FlatFieldContainer'>. It will be skipped.
# 2024-01-12 14:15:37,471 ctapipe.io.hdf5tableio.HDF5TableReader WARNING Table /tel_0/flatfield is missing column relative_time_median for field relative_time_median of container <class 'ctapipe.containers.FlatFieldContainer'>. It will be skipped.
# 2024-01-12 14:15:37,472 ctapipe.io.hdf5tableio.HDF5TableReader WARNING Table /tel_0/flatfield is missing column charge_median_outliers for field charge_median_outliers of container <class 'ctapipe.containers.FlatFieldContainer'>. It will be skipped.
# 2024-01-12 14:15:37,473 ctapipe.io.hdf5tableio.HDF5TableReader WARNING Table /tel_0/flatfield is missing column charge_std_outliers for field charge_std_outliers of container <class 'ctapipe.containers.FlatFieldContainer'>. It will be skipped.
# 2024-01-12 14:15:37,474 ctapipe.io.hdf5tableio.HDF5TableReader WARNING Table /tel_0/flatfield is missing column time_median_outliers for field time_median_outliers of container <class 'ctapipe.containers.FlatFieldContainer'>. It will be skipped.
# 2024-01-12 14:15:37,481 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM] (core._setup_components): setup of components
# 2024-01-12 14:15:37,485 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM] (core._init_writer): initilization of writter in full mode

# %%
tool.start()
# Out:
# 2024-01-12 14:15:37,692 WARNING [nectarchain.FlatFieldSPENominalStdNectarCAM] (core.start): neither needed events number specified or events per slice, it may cause a memory error
# LightNectarCAMEventSource:   0%|          | 0/10000 [00:00<?, ?ev/s]2024-01-12 14:15:37,709 INFO [nectarchain.makers.component.chargesComponent] (chargesComponent._init_trigger_type): initialization of the ChargesMaker following trigger type : FLATFIELD
# LightNectarCAMEventSource: 100%|██████████| 10000/10000 [02:34<00:00, 64.91ev/s]

# %%
output = tool.finish(return_output_component=True, display=True, figpath=os.getcwd())
output
# Out:
# 2024-01-12 14:18:11,784 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM] (core.finish): finishing Tool
# 2024-01-12 14:18:11,788 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM] (core._finish_components): finishing components and writting to output file
# 2024-01-12 14:18:27,414 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM.FlatFieldSingleNominalSPEStdNectarCAMComponent.SPEnominalStdalgorithm] (spe_algorithm.__fix_parameters): updating parameters by fixing pp and n
# 2024-01-12 14:18:27,418 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM.FlatFieldSingleNominalSPEStdNectarCAMComponent.SPEnominalStdalgorithm] (spe_algorithm.run): running maker
# 2024-01-12 14:18:27,419 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM.FlatFieldSingleNominalSPEStdNectarCAMComponent.SPEnominalStdalgorithm] (spe_algorithm.run): checking asked pixels id
# 2024-01-12 14:18:27,422 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM.FlatFieldSingleNominalSPEStdNectarCAMComponent.SPEnominalStdalgorithm] (spe_algorithm.run): creation of the fits instance array
# 2024-01-12 14:18:27,487 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM.FlatFieldSingleNominalSPEStdNectarCAMComponent.SPEnominalStdalgorithm] (spe_algorithm._make_fit_array_from_parameters): creation of fit instance for pixel: 52
# 2024-01-12 14:18:27,548 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM.FlatFieldSingleNominalSPEStdNectarCAMComponent.SPEnominalStdalgorithm] (spe_algorithm._make_fit_array_from_parameters): creation of fit instance for pixel: 48
# 2024-01-12 14:18:27,551 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM.FlatFieldSingleNominalSPEStdNectarCAMComponent.SPEnominalStdalgorithm] (spe_algorithm.run): running fits
# 2024-01-12 14:18:27,552 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM.FlatFieldSingleNominalSPEStdNectarCAMComponent.SPEnominalStdalgorithm] (spe_algorithm.run): pooling with nproc 10, chunksize 1
# 2024-01-12 14:18:29,028 INFO [nectarchain.makers.component.spe.spe_algorithm] (spe_algorithm.run_fit): Starting
# 2024-01-12 14:18:29,028 INFO [nectarchain.makers.component.spe.spe_algorithm] (spe_algorithm.run_fit): Starting
# 2024-01-12 14:18:34,103 INFO [nectarchain.makers.component.spe.spe_algorithm] (spe_algorithm.run_fit): Finished
# 2024-01-12 14:18:34,517 INFO [nectarchain.makers.component.spe.spe_algorithm] (spe_algorithm.run_fit): Finished
# 2024-01-12 14:18:34,888 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM.FlatFieldSingleNominalSPEStdNectarCAMComponent.SPEnominalStdalgorithm] (spe_algorithm.run): time for multiproc with starmap_async execution is 7.34e+00 sec
# 2024-01-12 14:18:34,891 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM.FlatFieldSingleNominalSPEStdNectarCAMComponent.SPEnominalStdalgorithm] (spe_algorithm.run): filling result table from fits results
# 2024-01-12 14:18:35,052 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM.FlatFieldSingleNominalSPEStdNectarCAMComponent.SPEnominalStdalgorithm] (spe_algorithm.run): plotting
# 2024-01-12 14:18:35,550 INFO [nectarchain.makers.component.spe.spe_algorithm] (spe_algorithm.run): time for plotting 2 pixels : 4.96e-01 sec
# 2024-01-12 14:18:35,554 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM.FlatFieldSingleNominalSPEStdNectarCAMComponent] (FlatFieldSPEComponent.finish): convergence rate : 1.0
# 2024-01-12 14:18:35,559 INFO [nectarchain.makers.core] (core._finish_components): [nectarchain.data.container.gainContainer.SPEfitContainer:
#                       is_valid: is_valid with default None as a 1-D array with
#                                 dtype bool with type <class 'numpy.ndarray'>
#                      high_gain: high gain with default None as a 2-D array with
#                                 dtype float64 with type <class 'numpy.ndarray'>
#                       low_gain: low gain with default None as a 2-D array with
#                                 dtype float64 with type <class 'numpy.ndarray'>
#                      pixels_id: pixel ids with default None as a 1-D array with
#                                 dtype uint16 with type <class 'numpy.ndarray'>
#                     likelihood: likelihood with default None as a 1-D array with
#                                 dtype float64 with type <class 'numpy.ndarray'>
#                        p_value: p_value with default None as a 1-D array with
#                                 dtype float64 with type <class 'numpy.ndarray'>
#                       pedestal: pedestal with default None as a 2-D array with
#                                 dtype float64 with type <class 'numpy.ndarray'>
#                  pedestalWidth: pedestalWidth with default None as a 2-D array
#                                 with dtype float64 with type <class
#                                 'numpy.ndarray'>
#                     resolution: resolution with default None as a 2-D array with
#                                 dtype float64 with type <class 'numpy.ndarray'>
#                     luminosity: luminosity with default None as a 2-D array with
#                                 dtype float64 with type <class 'numpy.ndarray'>
#                           mean: mean with default None as a 2-D array with dtype
#                                 float64 with type <class 'numpy.ndarray'>
#                              n: n with default None as a 2-D array with dtype
#                                 float64 with type <class 'numpy.ndarray'>
#                             pp: pp with default None as a 2-D array with dtype
#                                 float64 with type <class 'numpy.ndarray'>]
# 2024-01-12 14:18:35,613 INFO [nectarchain.FlatFieldSPENominalStdNectarCAM] (tool.finish): Goodbye
# 2024-01-12 14:18:35,615 WARNING [nectarchain.FlatFieldSPENominalStdNectarCAM] (core.finish): Shutting down.
# [nectarchain.data.container.gainContainer.SPEfitContainer:
#                        is_valid: is_valid with default None as a 1-D array with
#                                  dtype bool with type <class 'numpy.ndarray'>
#                       high_gain: high gain with default None as a 2-D array with
#                                  dtype float64 with type <class 'numpy.ndarray'>
#                        low_gain: low gain with default None as a 2-D array with
#                                  dtype float64 with type <class 'numpy.ndarray'>
#                       pixels_id: pixel ids with default None as a 1-D array with
#                                  dtype uint16 with type <class 'numpy.ndarray'>
#                      likelihood: likelihood with default None as a 1-D array with
#                                  dtype float64 with type <class 'numpy.ndarray'>
#                         p_value: p_value with default None as a 1-D array with
#                                  dtype float64 with type <class 'numpy.ndarray'>
#                        pedestal: pedestal with default None as a 2-D array with
#                                  dtype float64 with type <class 'numpy.ndarray'>
#                   pedestalWidth: pedestalWidth with default None as a 2-D array
#                                  with dtype float64 with type <class
#                                  'numpy.ndarray'>
#                      resolution: resolution with default None as a 2-D array with
#                                  dtype float64 with type <class 'numpy.ndarray'>
#                      luminosity: luminosity with default None as a 2-D array with
#                                  dtype float64 with type <class 'numpy.ndarray'>
#                            mean: mean with default None as a 2-D array with dtype
#                                  float64 with type <class 'numpy.ndarray'>
#                               n: n with default None as a 2-D array with dtype
#                                  float64 with type <class 'numpy.ndarray'>
#                              pp: pp with default None as a 2-D array with dtype
#                                  float64 with type <class 'numpy.ndarray'>]

# %%
output[0].resolution
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/ggroller/projects/nectarchain/notebooks/tool_implementation/tuto_SPE.ipynb Cellule 10 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Blpnhess/home/ggroller/projects/nectarchain/notebooks/tool_implementation/tuto_SPE.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> output[0].resolution
#
# AttributeError: 'NoneType' object has no attribute 'resolution'
